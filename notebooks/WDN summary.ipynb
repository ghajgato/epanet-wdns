# %%
import os
from epynet import Network

# %%
fn = 'anytown'

# %%
fn = os.path.join('..', 'water_distribution_networks', 'original', fn+'.inp')
wdn = Network(fn)
wdn.solve()
# Out:
# ---------------------------------------------------------------------------
# ENtoolkitError                            Traceback (most recent call last)
# <ipython-input-3-1603ea7cbf43> in <module>
#       1 fn = os.path.join('..', 'water_distribution_networks', 'original', fn+'.inp')
# ----> 2 wdn = Network(fn)
#       3 wdn.solve()
#
# ~/miniconda3/envs/epanet-wdns/lib/python3.8/site-packages/epynet/network.py in __init__(self, inputfile, units, headloss, charset)
#      21             self.rptfile = self.inputfile[:-3]+"rpt"
#      22             self.binfile = self.inputfile[:-3]+"bin"
# ---> 23             self.ep.ENopen(self.inputfile, self.rptfile, self.binfile)
#      24         else:
#      25             self.inputfile = False
#
# ~/miniconda3/envs/epanet-wdns/lib/python3.8/site-packages/epynet/epanet2.py in ENopen(self, nomeinp, nomerpt, nomebin)
#      82                           ctypes.c_char_p(nomebin.encode()))
#      83         if ierr!=0:
# ---> 84           raise ENtoolkitError(self, ierr)
#      85
#      86
#
# ENtoolkitError: Error 200: one or more errors in input file

# %%
print('# of nodes: {:>6}.'.format(len(wdn.nodes)))
print('# of pipes: {:>6}.'.format(len(wdn.pipes)))
print('# of pumps: {:>6}.'.format(len(wdn.pumps)))
print('# of valves: {:>5}.'.format(len(wdn.valves)))
print('# of tanks: {:>6}.'.format(len(wdn.tanks)))
print('# of reservoirs: {:>0}.'.format(len(wdn.reservoirs)))
