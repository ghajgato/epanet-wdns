# %%
import os
from epynet import Network

# %%
fn = 'Richmond_standard.inp'

# %%
fn = os.path.join('..', 'water_distribution_networks', 'original', fn)
wdn = Network(fn)
wdn.solve()

# %%
print('# of nodes: {:>5}.'.format(len(wdn.nodes)))
print('# of pipes: {:>5}.'.format(len(wdn.pipes)))
print('# of pumps: {:>5}.'.format(len(wdn.pumps)))
print('# of valves: {:>4}.'.format(len(wdn.valves)))
# Out:
# # of nodes:   872.
# # of pipes:   949.
# # of pumps:     7.
# # of valves:    1.
